# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
q=pd.read_csv(r"C:\Users\admin\OneDrive\Documents\clean_data.csv")

# %%
q
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              1                      Honda Jazz V     Chennai  2011
# 2              2                 Maruti Ertiga VDI     Chennai  2012
# 3              3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        5842                  Maruti Swift VDI       Delhi  2014
# 5843        5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        5845                Maruti Wagon R VXI     Kolkata  2013
# 5846        5846             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
from matplotlib import pyplot as plt
q['Year'].plot(kind='hist', bins=20, title='Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#bar chart
transmission_counts = q['Transmission'].value_counts()
plt.figure(figsize=(8, 6))
transmission_counts.plot(kind='bar', color='blue')
plt.xlabel('Transmission')
plt.ylabel('Number of Cars')
plt.title('Bar Chart of Transmission Types')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
#Pie chart
fuel_type_counts = q['Fuel_Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(fuel_type_counts, labels=fuel_type_counts.index, autopct='%1.1f%%', startangle=140, colors=['black', 'red', 'yellow', 'blue'])
plt.axis('equal')
plt.title('Pie Chart of Fuel Types')
plt.show()

# %%
# question c
q1= pd.get_dummies(q, columns=['Fuel_Type', 'Transmission'])

# %%
q1
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              1                      Honda Jazz V     Chennai  2011
# 2              2                 Maruti Ertiga VDI     Chennai  2012
# 3              3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        5842                  Maruti Swift VDI       Delhi  2014
# 5843        5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        5845                Maruti Wagon R VXI     Kolkata  2013
# 5846        5846             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# ...

# %%
#question D
from datetime import datetime
# Calculate current year by C_Y
c_y = datetime.now().year

# Calculate the age of the car
q1['Car_Age'] = c_y - q1['Year']

# %%
q1.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           1                      Honda Jazz V     Chennai  2011
# 2           2                 Maruti Ertiga VDI     Chennai  2012
# 3           3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           4            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First    19.67  1582.0  126.20    5.0  12.50
# 1              46000      First    18.19  1199.0   88.70    5.0   4.50
# 2              87000      First    20.77  1248.0   88.76    7.0   6.00
# 3              40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4              86999      First    23.08  1461.0   63.10    5.0   3.50
#
#    Fuel_Type_Diesel  Fuel_Type_Electric  Fuel_Type_Petrol  \
# 0                 1                   0                 0
# ...

# %%
# Define function
def c_e_c(engine):
    if engine <= 1390:
        return 'Small'
    elif 1390 < engine <= 1950:
        return 'Medium'
    else:
        return 'Big'

# create the new column 'Engine_Capacity'
q1['Engine_Capacity'] = q1['Engine'].apply(c_e_c)

# %%
q1.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1           1                      Honda Jazz V     Chennai  2011
# 2           2                 Maruti Ertiga VDI     Chennai  2012
# 3           3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4           4            Nissan Micra Diesel XV      Jaipur  2013
#
#    Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0              41000      First    19.67  1582.0  126.20    5.0  12.50
# 1              46000      First    18.19  1199.0   88.70    5.0   4.50
# 2              87000      First    20.77  1248.0   88.76    7.0   6.00
# 3              40670     Second    15.20  1968.0  140.80    5.0  17.74
# 4              86999      First    23.08  1461.0   63.10    5.0   3.50
#
#    Fuel_Type_Diesel  Fuel_Type_Electric  Fuel_Type_Petrol  \
# 0                 1                   0                 0
# ...

# %%
ecc = q1['Engine_Capacity'].value_counts()

#  bar chart
plt.figure(figsize=(8, 6))
engine_capacity_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Engine Capacity')
plt.xlabel('Engine Capacity')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#pie chart
plt.figure(figsize=(8, 6))
engine_capacity_counts.plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'lightblue', 'lightcoral'], startangle=140)
plt.title('Distributed of Engine Capacity')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %%
#Question E
#columns selection
c1 = q1[['Mileage','Engine','Power','Seats','Price']]

print("c1")
print(c1)
# Out:
# c1
#       Mileage  Engine   Power  Seats  Price
# 0       19.67  1582.0  126.20    5.0  12.50
# 1       18.19  1199.0   88.70    5.0   4.50
# 2       20.77  1248.0   88.76    7.0   6.00
# 3       15.20  1968.0  140.80    5.0  17.74
# 4       23.08  1461.0   63.10    5.0   3.50
# ...       ...     ...     ...    ...    ...
# 5842    28.40  1248.0   88.80    5.0   4.75
# 5843    24.40  1120.0   88.80    5.0   4.00
# 5844    14.00  2498.0   88.80    8.0   2.90
# 5845    18.90   998.0   67.10    5.0   2.65
# 5846    25.44   936.0   57.60    5.0   2.50
#
# [5847 rows x 5 columns]

# %%
#Filtered Data
fd = q1[q1['Fuel_Type_Diesel'] == 1]

nrfd = len(fd)


print("\nFiltered Data (Diesel cars only):")
print("Number of rows in the filtered data:", nrfd)
print(fd)
# Out:
# Filtered Data (Diesel cars only):
# Number of rows in the filtered data: 3161
#       Unnamed: 0                               Name    Location  Year  \
# 0              0   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                  Maruti Ertiga VDI     Chennai  2012
# 3              3    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4             Nissan Micra Diesel XV      Jaipur  2013
# 5              5  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# ...          ...                                ...         ...   ...
# 5841        5841              Honda Amaze VX i-DTEC  Coimbatore  2015
# 5842        5842                   Maruti Swift VDI       Delhi  2014
# 5843        5843           Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844              Mahindra Xylo D4 BSIV      Jaipur  2012
# 5846        5846              Chevrolet Beat Diesel   Hyderabad  2011
#
# ...

# %%
#rename 
r = q1.rename(columns={'Location': 'Locality', 'Mileage': 'Mileage_kmpl'})

print("\nRenamed Columns:")
print(r)
# Out:
# Renamed Columns:
#       Unnamed: 0                              Name    Locality  Year  \
# 0              0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              1                      Honda Jazz V     Chennai  2011
# 2              2                 Maruti Ertiga VDI     Chennai  2012
# 3              3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        5842                  Maruti Swift VDI       Delhi  2014
# 5843        5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        5845                Maruti Wagon R VXI     Kolkata  2013
# 5846        5846             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage_kmpl  Engine   Power  Seats  \
# ...

# %%
#mutate
q1['Price_in_lakhs'] = q1['Price'] * 100000

print("\nMutated DataFrame with Price in Lakh:")
print(q1)
# Out:
# Mutated DataFrame with Price in Lakh:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              1                      Honda Jazz V     Chennai  2011
# 2              2                 Maruti Ertiga VDI     Chennai  2012
# 3              3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        5842                  Maruti Swift VDI       Delhi  2014
# 5843        5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        5845                Maruti Wagon R VXI     Kolkata  2013
# 5846        5846             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# ...

# %%
# scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(q1['Engine'], q1['Price'], color='blue', alpha=0.5)
plt.xlabel('Engine (CC)')
plt.ylabel('Price (in Lakhs)')
plt.title('Scatter Plot of Engine vs. Price')
plt.grid(True)
plt.show()

# %%
# Arrange
s_y = q1.sort_values(by='Year', ascending=False)

print("\nSorted DataFrame by Year:")
print(s_y)
# Out:
# Sorted DataFrame by Year:
#       Unnamed: 0                               Name    Location  Year  \
# 5405        5405          Renault KWID RXT Optional       Kochi  2019
# 942          942    Ford Endeavour 2.2 Trend AT 4X2       Kochi  2019
# 5533        5533          Maruti Omni 5 Seater BSIV  Coimbatore  2019
# 770          770              Mahindra XUV500 W9 AT  Coimbatore  2019
# 4267        4267         Maruti Swift Dzire AMT ZDI     Chennai  2019
# ...          ...                                ...         ...   ...
# 1185        1185                      Maruti Zen VX      Jaipur  1999
# 1791        1791                 Honda City 1.3 EXI        Pune  1999
# 3630        3630  Mercedes-Benz E-Class 250 D W 210      Mumbai  1998
# 5558        5558                      Maruti Zen LX      Jaipur  1998
# 3039        3039                     Maruti Zen LXI      Jaipur  1998
#
#       Kilometers_Driven Owner_Type  Mileage  Engine  Power  Seats  Price  \
# ...

# %%
s_m = q1.sort_values(by='Mileage', ascending=False)

print("\nSorted DataFrame by Mileage of the car:")
print(s_m)
# Out:
# Sorted DataFrame by Mileage of the car:
#       Unnamed: 0                                         Name    Location  \
# 864          864                             Maruti Swift ZDI       Delhi
# 2361        2361                             Maruti Dzire VDI   Hyderabad
# 2670        2670                         Maruti Swift AMT VDI       Delhi
# 1208        1208                             Maruti Swift VDI       Kochi
# 4198        4198                        Maruti Swift DDiS VDI  Coimbatore
# ...          ...                                          ...         ...
# 4022        4022                 Land Rover Range Rover 3.0 D      Mumbai
# 524          524  Mercedes-Benz New C-Class Progressive C 200       Kochi
# 186          186                           Honda City 1.5 GXI   Ahmedabad
# 2593        2593                      Skoda Superb 3.6 V6 FSI   Hyderabad
# 1267        1267          Mercedes-Benz M-Class ML 350 4Matic   Bangalore
#
# ...

# %%
#group operations
g_s = q1.groupby('Location').agg({'Price': 'mean', 'Year': 'max'}).reset_index()
print("\nGrouped Summary by Location:")
print(g_s)
# Out:
# Grouped Summary by Location:
#       Location      Price  Year
# 0    Ahmedabad   8.567248  2019
# 1    Bangalore  13.482670  2018
# 2      Chennai   7.958340  2019
# 3   Coimbatore  15.160206  2019
# 4        Delhi   9.881944  2019
# 5    Hyderabad   9.997423  2019
# 6       Jaipur   5.916725  2019
# 7        Kochi  11.309109  2019
# 8      Kolkata   5.733924  2019
# 9       Mumbai   9.592546  2019
# 10        Pune   6.951000  2019

# %%
g_d = q1.groupby(['Location', 'Year']).size().reset_index(name='Count')

print(g_d)
# Out:
#       Location  Year  Count
# 0    Ahmedabad  2002      1
# 1    Ahmedabad  2004      1
# 2    Ahmedabad  2005      1
# 3    Ahmedabad  2007      5
# 4    Ahmedabad  2008      8
# ..         ...   ...    ...
# 187       Pune  2015     54
# 188       Pune  2016     57
# 189       Pune  2017     42
# 190       Pune  2018     22
# 191       Pune  2019      1
#
# [192 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
c_l = q1.groupby('Location').size().reset_index(name='Number_of_Cars')

print(c_l)
# Out:
#       Location  Number_of_Cars
# 0    Ahmedabad             218
# 1    Bangalore             352
# 2      Chennai             476
# 3   Coimbatore             631
# 4        Delhi             540
# 5    Hyderabad             710
# 6       Jaipur             403
# 7        Kochi             640
# 8      Kolkata             525
# 9       Mumbai             762
# 10        Pune             590

# %%
#pie chart
plt.figure(figsize=(8, 6))
plt.pie(c_l['Number_of_Cars'], labels=c_l['Location'], autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Number of Cars by Location')
plt.show()

# %%
#group by
g_d = q1.groupby('Car_Age').size().reset_index(name='Cars_Count')

print("Grouped data by car age:")
print(g_d)
# Out:
# Grouped data by car age:
#     Car_Age  Cars_Count
# 0         5         101
# 1         6         294
# 2         7         582
# 3         8         734
# 4         9         734
# 5        10         784
# 6        11         631
# 7        12         558
# 8        13         455
# 9        14         330
# 10       15         193
# 11       16         163
# 12       17         106
# 13       18          69
# 14       19          44
# 15       20          27
# 16       21          16
# 17       22          12
# 18       23           5
# 19       24           4
# 20       25           2
# 21       26           3

# %%
#bar graph
plt.figure(figsize=(10, 6))
plt.bar(g_d['Car_Age'], g_d['Cars_Count'], color='green')
plt.xlabel('Car Age')
plt.ylabel('No of Cars')
plt.title('No of Cars by Car Age')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
q1
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              1                      Honda Jazz V     Chennai  2011
# 2              2                 Maruti Ertiga VDI     Chennai  2012
# 3              3   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              4            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        5842                  Maruti Swift VDI       Delhi  2014
# 5843        5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        5844             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        5845                Maruti Wagon R VXI     Kolkata  2013
# 5846        5846             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  Price  \
# ...

# %%
#correlation
plt.figure(figsize=(12, 8))
sns.heatmap(q1.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
